# %% [markdown]
# <a href="https://colab.research.google.com/github/Pashem1/My_First_Test_Repo/blob/main/testmarkdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
# ## Нужно сделать:
# 1. 1. Список
# 2. 2. Рисунок
# 3. 3. Таблицу
# 4. 4. Ссылку
#
# ![Блок 1 цвет.png](data:image/png;base64,...)
#
# | A | B | C |
# |---|---|---|
# |11 |22 |33 |
# |aa |bb |cc |
#
# [Ссылка на руководство по Markdown](https://youtu.be/AXpSup9ZKsI?si=xX7vHQ3JS1_amAEy)
#
# - добавленная пометка
